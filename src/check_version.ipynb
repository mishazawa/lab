# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import Image

# %%
img = cv2.imread("../assets/test_img.png", 0)

# %%
plt.imshow(img, cmap='gray')

# %%
Image("../assets/test_img.png")
